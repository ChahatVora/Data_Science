# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\chahat\Downloads\matches.csv",na_values=['nan',' ','na'])
df1 = pd.read_csv(r"C:\Users\chahat\Downloads\deliveries.csv",na_values=['nan',' ','na'])
df.head(10)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 5  335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 6  335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 8  335990  2007/08   Hyderabad  2008-04-24     League       YK Pathan
# 9  335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# ...

# %%
print(df.shape,df1.shape)
# Out:
# (1095, 20) (260920, 17)

# %%
print(df.columns,df1.columns)
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object') Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df = df.rename(columns={'id':'match_id'})

# %%
df = pd.merge(df,df1,on='match_id')

# %%
df.shape
# Out:
# (260920, 36)

# %%
df.columns
# Out:
# Index(['match_id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    match_id   season       city        date match_type player_of_match  \
# 0    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 5    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 6    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 7    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 8    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 9    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 36 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   season            260920 non-null  object
#  2   city              248523 non-null  object
#  3   date              260920 non-null  object
#  4   match_type        260920 non-null  object
#  5   player_of_match   260430 non-null  object
#  6   venue             260920 non-null  object
#  7   team1             260920 non-null  object
#  8   team2             260920 non-null  object
#  9   toss_winner       260920 non-null  object
#  10  toss_decision     260920 non-null  object
#  11  winner            260430 non-null  object
#  12  result            260920 non-null  object
#  13  result_margin     256796 non-null  float64
#  14  target_runs       260611 non-null  float64
#  15  target_overs      260611 non-null  float64
# ...

# %%
df.describe()
# Out:
#            match_id  result_margin    target_runs   target_overs  \
# count  2.609200e+05  256796.000000  260611.000000  260611.000000
# mean   9.070665e+05      17.279451     167.290406      19.846742
# std    3.679913e+05      21.600307      32.165944       1.224266
# min    3.359820e+05       1.000000      43.000000       5.000000
# 25%    5.483340e+05       6.000000     148.000000      20.000000
# 50%    9.809670e+05       8.000000     167.000000      20.000000
# 75%    1.254066e+06      20.000000     188.000000      20.000000
# max    1.426312e+06     146.000000     288.000000      20.000000
#
#               inning           over           ball   batsman_runs  \
# count  260920.000000  260920.000000  260920.000000  260920.000000
# mean        1.483531       9.197677       3.624486       1.265001
# std         0.502643       5.683484       1.814920       1.639298
# min         1.000000       0.000000       1.000000       0.000000
# ...

# %%
a = df.select_dtypes(include=['object']).columns
b = df.select_dtypes(include=['int64']).columns
c = df.select_dtypes(include=['float64']).columns
print(a,"\n",b,"\n",c)
# Out:
# Index(['season', 'city', 'date', 'match_type', 'player_of_match', 'venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'super_over', 'method', 'umpire1', 'umpire2', 'batting_team',
#        'bowling_team', 'batter', 'bowler', 'non_striker', 'extras_type',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')
#  Index(['match_id', 'inning', 'over', 'ball', 'batsman_runs', 'extra_runs',
#        'total_runs', 'is_wicket'],
#       dtype='object')
#  Index(['result_margin', 'target_runs', 'target_overs'], dtype='object')

# %%
for i in a:
    print(df[i].unique())
# Out:
# ['2007/08' '2009' '2009/10' '2011' '2012' '2013' '2014' '2015' '2016'
#  '2017' '2018' '2019' '2020/21' '2021' '2022' '2023' '2024']
# ['Bangalore' 'Chandigarh' 'Delhi' 'Mumbai' 'Kolkata' 'Jaipur' 'Hyderabad'
#  'Chennai' 'Cape Town' 'Port Elizabeth' 'Durban' 'Centurion' 'East London'
#  'Johannesburg' 'Kimberley' 'Bloemfontein' 'Ahmedabad' 'Cuttack' 'Nagpur'
#  'Dharamsala' 'Kochi' 'Indore' 'Visakhapatnam' 'Pune' 'Raipur' 'Ranchi'
#  'Abu Dhabi' nan 'Rajkot' 'Kanpur' 'Bengaluru' 'Dubai' 'Sharjah'
#  'Navi Mumbai' 'Lucknow' 'Guwahati' 'Mohali']
# ['2008-04-18' '2008-04-19' '2008-04-20' '2008-04-21' '2008-04-22'
#  '2008-04-23' '2008-04-24' '2008-04-25' '2008-04-26' '2008-04-27'
#  '2008-04-28' '2008-04-29' '2008-04-30' '2008-05-01' '2008-05-02'
#  '2008-05-03' '2008-05-04' '2008-05-05' '2008-05-06' '2008-05-07'
#  '2008-05-08' '2008-05-09' '2008-05-10' '2008-05-11' '2008-05-12'
#  '2008-05-13' '2008-05-14' '2008-05-15' '2008-05-16' '2008-05-17'
# ...

# %%
df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
df['team1'] = df['team1'].replace({'Royal Challengers Bangalore':'Royal Challengers Bengaluru','Kings XI Punjab':'Punjab Kings',
                           'Delhi Daredevils':'Delhi Capitals','Rising Pune Supergiants':'Rising Pune Supergiant'})

# %%
df['team1'].unique()
# Out:
# array(['Royal Challengers Bengaluru', 'Punjab Kings', 'Delhi Capitals',
#        'Mumbai Indians', 'Kolkata Knight Riders', 'Rajasthan Royals',
#        'Deccan Chargers', 'Chennai Super Kings', 'Kochi Tuskers Kerala',
#        'Pune Warriors', 'Sunrisers Hyderabad', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Lucknow Super Giants', 'Gujarat Titans'],
#       dtype=object)

# %%
df['team2'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Deccan Chargers',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Gujarat Titans', 'Lucknow Super Giants',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
df['team2'] = df['team2'].replace({'Royal Challengers Bangalore':'Royal Challengers Bengaluru','Kings XI Punjab':'Punjab Kings',
                           'Delhi Daredevils':'Delhi Capitals','Rising Pune Supergiants':'Rising Pune Supergiant'})

# %%
df['team2'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bengaluru', 'Deccan Chargers', 'Punjab Kings',
#        'Delhi Capitals', 'Mumbai Indians', 'Kochi Tuskers Kerala',
#        'Pune Warriors', 'Sunrisers Hyderabad', 'Rising Pune Supergiant',
#        'Gujarat Lions', 'Gujarat Titans', 'Lucknow Super Giants'],
#       dtype=object)

# %%
df['toss_winner'] = df['toss_winner'].replace({'Royal Challengers Bangalore':'Royal Challengers Bengaluru','Kings XI Punjab':'Punjab Kings',
                           'Delhi Daredevils':'Delhi Capitals','Rising Pune Supergiants':'Rising Pune Supergiant'})

# %%
df['toss_winner'].unique()
# Out:
# array(['Royal Challengers Bengaluru', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Mumbai Indians', 'Deccan Chargers',
#        'Punjab Kings', 'Kolkata Knight Riders', 'Delhi Capitals',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiant', 'Gujarat Titans',
#        'Lucknow Super Giants'], dtype=object)

# %%
df['winner'] = df['winner'].replace({'Royal Challengers Bangalore':'Royal Challengers Bengaluru','Kings XI Punjab':'Punjab Kings',
                           'Delhi Daredevils':'Delhi Capitals','Rising Pune Supergiants':'Rising Pune Supergiant'})

# %%
df['winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Capitals',
#        'Royal Challengers Bengaluru', 'Rajasthan Royals', 'Punjab Kings',
#        'Deccan Chargers', 'Mumbai Indians', 'Pune Warriors',
#        'Kochi Tuskers Kerala', nan, 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Gujarat Lions', 'Gujarat Titans',
#        'Lucknow Super Giants'], dtype=object)

# %%
df['batting_team'] = df['batting_team'].replace({'Royal Challengers Bangalore':'Royal Challengers Bengaluru','Kings XI Punjab':'Punjab Kings',
                           'Delhi Daredevils':'Delhi Capitals','Rising Pune Supergiants':'Rising Pune Supergiant'})

# %%
df['batting_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Royal Challengers Bengaluru',
#        'Chennai Super Kings', 'Punjab Kings', 'Rajasthan Royals',
#        'Delhi Capitals', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Gujarat Lions', 'Lucknow Super Giants',
#        'Gujarat Titans'], dtype=object)

# %%
df['bowling_team'] = df['bowling_team'].replace({'Royal Challengers Bangalore':'Royal Challengers Bengaluru','Kings XI Punjab':'Punjab Kings',
                           'Delhi Daredevils':'Delhi Capitals','Rising Pune Supergiants':'Rising Pune Supergiant'})

# %%
df['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bengaluru', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Chennai Super Kings', 'Delhi Capitals',
#        'Rajasthan Royals', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Gujarat Lions', 'Gujarat Titans',
#        'Lucknow Super Giants'], dtype=object)

# %%
df['season'] = df['season'].replace({'2007/08':'2008','2009/10':'2010','2020/21':'2020'})

# %%
df['season'].unique()
# Out:
# array(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023',
#        '2024'], dtype=object)

# %%
df['city'] = df['city'].replace({'Bangalore':'Bengaluru'})

# %%
df['city'].unique()
# Out:
# array(['Bengaluru', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', nan, 'Rajkot', 'Kanpur', 'Dubai', 'Sharjah',
#        'Navi Mumbai', 'Lucknow', 'Guwahati', 'Mohali'], dtype=object)

# %%
df['match_type'].unique()
# Out:
# array(['League', 'Semi Final', 'Final', '3rd Place Play-Off',
#        'Qualifier 1', 'Elimination Final', 'Qualifier 2', 'Eliminator'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# match_id                 0
# season                   0
# city                 12397
# date                     0
# match_type               0
# player_of_match        490
# venue                    0
# team1                    0
# team2                    0
# toss_winner              0
# toss_decision            0
# winner                 490
# result                   0
# result_margin         4124
# target_runs            309
# target_overs           309
# super_over               0
# method              257274
# umpire1                  0
# umpire2                  0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# ...

# %%
df['city'].unique()
# Out:
# array(['Bengaluru', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', nan, 'Rajkot', 'Kanpur', 'Dubai', 'Sharjah',
#        'Navi Mumbai', 'Lucknow', 'Guwahati', 'Mohali'], dtype=object)

# %%
df['team1'].unique()
# Out:
# array(['Royal Challengers Bengaluru', 'Punjab Kings', 'Delhi Capitals',
#        'Mumbai Indians', 'Kolkata Knight Riders', 'Rajasthan Royals',
#        'Deccan Chargers', 'Chennai Super Kings', 'Kochi Tuskers Kerala',
#        'Pune Warriors', 'Sunrisers Hyderabad', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Lucknow Super Giants', 'Gujarat Titans'],
#       dtype=object)

# %%
df.groupby('venue')['city'].unique()
# Out:
# venue
# Arun Jaitley Stadium                                                                   [Delhi]
# Arun Jaitley Stadium, Delhi                                                            [Delhi]
# Barabati Stadium                                                                     [Cuttack]
# Barsapara Cricket Stadium, Guwahati                                                 [Guwahati]
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow                [Lucknow]
# Brabourne Stadium                                                                     [Mumbai]
# Brabourne Stadium, Mumbai                                                             [Mumbai]
# Buffalo Park                                                                     [East London]
# De Beers Diamond Oval                                                              [Kimberley]
# Dr DY Patil Sports Academy                                                            [Mumbai]
# ...

# %%
df[df['city'].isna()]['venue'].unique()
# Out:
# array(['Sharjah Cricket Stadium', 'Dubai International Cricket Stadium'],
#       dtype=object)

# %%
new_city = {
    'Sharjah Cricket Stadium':'Sharjah',
    'Dubai International Cricket Stadium':'Dubai'
}
df['city'] = df['city'].fillna(df['venue'].map(new_city))

# %%
df['city'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['city'].unique()
# Out:
# array(['Bengaluru', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Sharjah', 'Dubai', 'Rajkot', 'Kanpur', 'Navi Mumbai',
#        'Lucknow', 'Guwahati', 'Mohali'], dtype=object)

# %%
df[df['player_of_match'].isna()]['date'].unique()
# Out:
# array(['2011-05-21', '2015-04-29', '2015-05-17', '2019-04-30',
#        '2023-05-03'], dtype=object)

# %%
df[df['player_of_match'].isna()]['team1'].unique()
# Out:
# array(['Delhi Capitals', 'Royal Challengers Bengaluru',
#        'Lucknow Super Giants'], dtype=object)

# %%
df[df['player_of_match'].isna()]['team2'].unique()
# Out:
# array(['Pune Warriors', 'Rajasthan Royals', 'Delhi Capitals',
#        'Chennai Super Kings'], dtype=object)

# %%
df[df['player_of_match'].isna()]['match_type'].unique()
# Out:
# array(['League'], dtype=object)

# %%
df['player_of_match'] = df['player_of_match'].fillna("match_cancelled")

# %%
df[df['winner'].isna()]['date'].unique()
# Out:
# array(['2011-05-21', '2015-04-29', '2015-05-17', '2019-04-30',
#        '2023-05-03'], dtype=object)

# %%
df['winner'] = df['winner'].fillna("match_cancelled")

# %%
df[df['result_margin'].isna()]['date'].unique()
# Out:
# array(['2009-04-23', '2010-03-21', '2011-05-21', '2013-04-07',
#        '2013-04-16', '2014-04-29', '2015-04-21', '2015-04-29',
#        '2015-05-17', '2017-04-29', '2019-03-30', '2019-04-30',
#        '2019-05-02', '2020-09-20', '2020-09-28', '2020-10-18',
#        '2021-04-25', '2023-05-03'], dtype=object)

# %%
new_margin = {
    '2009-04-23':999,
    '2010-03-21':999,
    '2011-05-21':999,
    '2013-04-07':999,
    '2013-04-16':999,
    '2014-04-29':999,
    '2015-04-21':999,
    '2015-04-29':999,
    '2015-05-17':999,
    '2017-04-29':999,
    '2019-03-30':999,
    '2019-04-30':999,
    '2019-05-02':999,
    '2020-09-20':999,
    '2020-09-28':999,
    '2020-10-18':999,
    '2021-04-25':999,
    '2023-05-03':999
}
df['result_margin'] = df['result_margin'].fillna(df['date'].map(new_margin))

# %%
df[(df['result_margin'].isna()) & (df['date']=='2019-05-02')][['team1','team2']]
# Out:
# Empty DataFrame
# Columns: [team1, team2]
# Index: []

# %%
df[df['target_runs'].isna()]['date'].unique()
# Out:
# array(['2011-05-21', '2015-04-29', '2023-05-03'], dtype=object)

# %%
df[(df['date']=='2015-05-17')]['target_runs'].unique()
# Out:
# array([188., 114.])

# %%
df['target_runs'].describe()
# Out:
# count    260611.000000
# mean        167.290406
# std          32.165944
# min          43.000000
# 25%         148.000000
# 50%         167.000000
# 75%         188.000000
# max         288.000000
# Name: target_runs, dtype: float64

# %%
df[df['target_runs'].isna()]['winner'].unique()
# Out:
# array(['match_cancelled'], dtype=object)

# %%
df['target_runs'] = df['target_runs'].fillna(999)

# %%
df[df['target_overs'].isna()]['winner'].unique()
# Out:
# array(['match_cancelled'], dtype=object)

# %%
df['target_overs'] = df['target_overs'].fillna(999)

# %%
df['method'].unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
df[df['method']=='D/L']['date'].unique()
# Out:
# array(['2008-05-17', '2008-05-18', '2009-04-19', '2009-04-21',
#        '2009-05-07', '2011-04-18', '2011-05-07', '2011-05-14',
#        '2014-05-10', '2015-04-22', '2015-05-15', '2016-04-26',
#        '2016-05-14', '2016-05-17', '2016-05-18', '2017-05-17',
#        '2018-04-11', '2018-04-21', '2018-05-02', '2023-04-01',
#        '2023-05-29'], dtype=object)

# %%
df['method'] = df['method'].fillna('No_D/L')

# %%
df['extras_type'].unique()
# Out:
# array(['legbyes', nan, 'wides', 'byes', 'noballs', 'penalty'],
#       dtype=object)

# %%
df['extras_type'] = df['extras_type'].fillna('normal')

# %%
df['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'retired hurt',
#        'stumped', 'caught and bowled', 'hit wicket',
#        'obstructing the field', 'retired out'], dtype=object)

# %%
df['player_dismissed'] = df['player_dismissed'].fillna('No_wicket')

# %%
df['dismissal_kind'] = df['dismissal_kind'].fillna('No_wicket')

# %%
df['fielder'] = df['fielder'].fillna('No_wicket')

# %%
df.isnull().sum()
# Out:
# match_id            0
# season              0
# city                0
# date                0
# match_type          0
# player_of_match     0
# venue               0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# winner              0
# result              0
# result_margin       0
# target_runs         0
# target_overs        0
# super_over          0
# method              0
# umpire1             0
# umpire2             0
# inning              0
# batting_team        0
# bowling_team        0
# over                0
# ball                0
# batter              0
# bowler              0
# non_striker         0
# batsman_runs        0
# extra_runs          0
# total_runs          0
# extras_type         0
# is_wicket           0
# player_dismissed    0
# dismissal_kind      0
# fielder             0
# dtype: int64

# %%
df.to_csv('ipl.csv',index=False)

# %%
df['winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Capitals',
#        'Royal Challengers Bengaluru', 'Rajasthan Royals', 'Punjab Kings',
#        'Deccan Chargers', 'Mumbai Indians', 'Pune Warriors',
#        'Kochi Tuskers Kerala', 'match_cancelled', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Gujarat Lions', 'Gujarat Titans',
#        'Lucknow Super Giants'], dtype=object)

# %%
df[['team1','team2']]
# Out:
#                               team1                  team2
# 0       Royal Challengers Bengaluru  Kolkata Knight Riders
# 1       Royal Challengers Bengaluru  Kolkata Knight Riders
# 2       Royal Challengers Bengaluru  Kolkata Knight Riders
# 3       Royal Challengers Bengaluru  Kolkata Knight Riders
# 4       Royal Challengers Bengaluru  Kolkata Knight Riders
# ...                             ...                    ...
# 260915          Sunrisers Hyderabad  Kolkata Knight Riders
# 260916          Sunrisers Hyderabad  Kolkata Knight Riders
# 260917          Sunrisers Hyderabad  Kolkata Knight Riders
# 260918          Sunrisers Hyderabad  Kolkata Knight Riders
# 260919          Sunrisers Hyderabad  Kolkata Knight Riders
#
# [260920 rows x 2 columns]

# %%
df.reset_index(inplace=True)

# %%
df.loc[1]
# Out:
# index                                         1
# match_id                                 335982
# season                                     2008
# city                                  Bengaluru
# date                                 2008-04-18
# match_type                               League
# player_of_match                     BB McCullum
# venue                     M Chinnaswamy Stadium
# team1               Royal Challengers Bengaluru
# team2                     Kolkata Knight Riders
# toss_winner         Royal Challengers Bengaluru
# toss_decision                             field
# winner                    Kolkata Knight Riders
# result                                     runs
# result_margin                             140.0
# target_runs                               223.0
# target_overs                               20.0
# super_over                                    N
# method                                   No_D/L
# umpire1                               Asad Rauf
# ...

# %%
df.iloc[1]
# Out:
# index                                         1
# match_id                                 335982
# season                                     2008
# city                                  Bengaluru
# date                                 2008-04-18
# match_type                               League
# player_of_match                     BB McCullum
# venue                     M Chinnaswamy Stadium
# team1               Royal Challengers Bengaluru
# team2                     Kolkata Knight Riders
# toss_winner         Royal Challengers Bengaluru
# toss_decision                             field
# winner                    Kolkata Knight Riders
# result                                     runs
# result_margin                             140.0
# target_runs                               223.0
# target_overs                               20.0
# super_over                                    N
# method                                   No_D/L
# umpire1                               Asad Rauf
# ...

# %%
total = df[((df['team1']=='Royal Challengers Bengaluru') & (df['team2']=='Chennai Super Kings')) | 
    ((df['team2']=='Royal Challengers Bengaluru') & (df['team1']=='Chennai Super Kings'))]['date'].nunique()
total
# Out:
# 32

# %%
rcb = df[(((df['team1']=='Royal Challengers Bengaluru') & (df['team2']=='Chennai Super Kings')) | 
    ((df['team2']=='Royal Challengers Bengaluru') & (df['team1']=='Chennai Super Kings'))) &
    (df['winner']=='Royal Challengers Bengaluru')]['date'].nunique()
rcb
# Out:
# 11

# %%
csk = df[(((df['team1']=='Royal Challengers Bengaluru') & (df['team2']=='Chennai Super Kings')) | 
    ((df['team2']=='Royal Challengers Bengaluru') & (df['team1']=='Chennai Super Kings'))) &
    (df['winner']=='Chennai Super Kings')]['date'].nunique()
csk
# Out:
# 21

# %%
print('winning rate of rcb against csk is(upto 2024):-',rcb*100/total)
# Out:
# winning rate of rcb against csk is(upto 2024):- 34.375

# %%
print('winning rate of csk against rcb is(upto 2024):-',csk*100/total)
# Out:
# winning rate of csk against rcb is(upto 2024):- 65.625

# %%
df['season'].isin(['2008','2025']).unique()
# Out:
# array([ True, False])

# %%
df['target_runs'].between(43,288)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 260915    True
# 260916    True
# 260917    True
# 260918    True
# 260919    True
# Name: target_runs, Length: 260920, dtype: bool

# %%
df.query("(team1=='Mumbai Indians' and team2=='Chennai Super Kings')" or
         "(team2=='Mumbai Indians' and team1=='Chennai Super Kings')")
# Out:
#          index  match_id season     city        date match_type  \
# 8248      8248    336018   2008   Mumbai  2008-05-14     League
# 8249      8249    336018   2008   Mumbai  2008-05-14     League
# 8250      8250    336018   2008   Mumbai  2008-05-14     League
# 8251      8251    336018   2008   Mumbai  2008-05-14     League
# 8252      8252    336018   2008   Mumbai  2008-05-14     League
# ...        ...       ...    ...      ...         ...        ...
# 237790  237790   1359523   2023  Chennai  2023-05-06     League
# 237791  237791   1359523   2023  Chennai  2023-05-06     League
# 237792  237792   1359523   2023  Chennai  2023-05-06     League
# 237793  237793   1359523   2023  Chennai  2023-05-06     League
# 237794  237794   1359523   2023  Chennai  2023-05-06     League
#
#        player_of_match                                     venue  \
# 8248     ST Jayasuriya                          Wankhede Stadium
# ...

# %%
df[df['team1'].isna()]
# Out:
# Empty DataFrame
# Columns: [index, match_id, season, city, date, match_type, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, target_runs, target_overs, super_over, method, umpire1, umpire2, inning, batting_team, bowling_team, over, ball, batter, bowler, non_striker, batsman_runs, extra_runs, total_runs, extras_type, is_wicket, player_dismissed, dismissal_kind, fielder]
# Index: []
#
# [0 rows x 37 columns]

# %%
df[~df['team1'].isna()]
# Out:
#          index  match_id season       city        date match_type  \
# 0            0    335982   2008  Bengaluru  2008-04-18     League
# 1            1    335982   2008  Bengaluru  2008-04-18     League
# 2            2    335982   2008  Bengaluru  2008-04-18     League
# 3            3    335982   2008  Bengaluru  2008-04-18     League
# 4            4    335982   2008  Bengaluru  2008-04-18     League
# ...        ...       ...    ...        ...         ...        ...
# 260915  260915   1426312   2024    Chennai  2024-05-26      Final
# 260916  260916   1426312   2024    Chennai  2024-05-26      Final
# 260917  260917   1426312   2024    Chennai  2024-05-26      Final
# 260918  260918   1426312   2024    Chennai  2024-05-26      Final
# 260919  260919   1426312   2024    Chennai  2024-05-26      Final
#
#        player_of_match                                     venue  \
# 0          BB McCullum                     M Chinnaswamy Stadium
# ...

# %%
df.set_index('season',inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.set_index('index',inplace=True)

# %%
df.set_index(['season','city'],inplace=True)

# %%
df.loc['2016','Bengaluru']
# Out:
# C:\Users\chahat\AppData\Local\Temp\ipykernel_14500\1651803940.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc['2016','Bengaluru']
#                   match_id        date match_type player_of_match  \
# season city
# 2016   Bengaluru    980907  2016-04-12     League  AB de Villiers
#        Bengaluru    980907  2016-04-12     League  AB de Villiers
#        Bengaluru    980907  2016-04-12     League  AB de Villiers
#        Bengaluru    980907  2016-04-12     League  AB de Villiers
#        Bengaluru    980907  2016-04-12     League  AB de Villiers
# ...                    ...         ...        ...             ...
#        Bengaluru    981019  2016-05-29      Final     BCJ Cutting
#        Bengaluru    981019  2016-05-29      Final     BCJ Cutting
#        Bengaluru    981019  2016-05-29      Final     BCJ Cutting
#        Bengaluru    981019  2016-05-29      Final     BCJ Cutting
# ...

# %%
df.reset_index(inplace=True)

# %%
df.set_index('index',inplace=True)

# %%
df.duplicated('match_id').unique()
# Out:
# array([False,  True])

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260920 entries, 0 to 260919
# Data columns (total 36 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   season            260920 non-null  object
#  1   city              260920 non-null  object
#  2   match_id          260920 non-null  int64
#  3   date              260920 non-null  datetime64[ns]
#  4   match_type        260920 non-null  object
#  5   player_of_match   260920 non-null  object
#  6   venue             260920 non-null  object
#  7   team1             260920 non-null  object
#  8   team2             260920 non-null  object
#  9   toss_winner       260920 non-null  object
#  10  toss_decision     260920 non-null  object
#  11  winner            260920 non-null  object
#  12  result            260920 non-null  object
#  13  result_margin     260920 non-null  float64
#  14  target_runs       260920 non-null  float64
# ...

# %%
df.columns.str.strip()
# Out:
# Index(['season', 'city', 'match_id', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df['toss_decision'].unique()
# Out:
# array(['field', 'bat'], dtype=object)

# %%
df1 = df.copy()

# %%
df = df.drop(['player_of_match','result','result_margin','target_runs','target_overs','super_over',
         'method','umpire1','umpire2','inning','batting_team','bowling_team','over','ball','batter','bowler','non_striker',
         'batsman_runs','extra_runs','total_runs','extras_type','is_wicket','player_dismissed','dismissal_kind','fielder'],axis=1)

# %%
df.isnull().sum()
# Out:
# season           0
# city             0
# match_id         0
# date             0
# match_type       0
# venue            0
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# dtype: int64

# %%
df['year'] = df['date'].dt.year

# %%
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day

# %%
df = df.drop('date',axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['winner'] = le.fit_transform(df['winner'])

# %%
df
# Out:
#        season       city  match_id match_type  \
# index
# 0        2008  Bengaluru    335982     League
# 1        2008  Bengaluru    335982     League
# 2        2008  Bengaluru    335982     League
# 3        2008  Bengaluru    335982     League
# 4        2008  Bengaluru    335982     League
# ...       ...        ...       ...        ...
# 260915   2024    Chennai   1426312      Final
# 260916   2024    Chennai   1426312      Final
# 260917   2024    Chennai   1426312      Final
# 260918   2024    Chennai   1426312      Final
# 260919   2024    Chennai   1426312      Final
#
#                                            venue                        team1  \
# index
# 0                          M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 1                          M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 2                          M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 3                          M Chinnaswamy Stadium  Royal Challengers Bengaluru
# ...

# %%
cols = [
    'season',
    'city',
    'match_type',
    'venue',
    'team1',
    'team2',
    'toss_winner',
    'toss_decision'	
]
df = pd.get_dummies(df,columns=cols).astype('int')

# %%
df.columns
# Out:
# Index(['match_id', 'winner', 'year', 'month', 'day', 'season_2008',
#        'season_2009', 'season_2010', 'season_2011', 'season_2012',
#        ...
#        'toss_winner_Lucknow Super Giants', 'toss_winner_Mumbai Indians',
#        'toss_winner_Pune Warriors', 'toss_winner_Punjab Kings',
#        'toss_winner_Rajasthan Royals', 'toss_winner_Rising Pune Supergiant',
#        'toss_winner_Royal Challengers Bengaluru',
#        'toss_winner_Sunrisers Hyderabad', 'toss_decision_bat',
#        'toss_decision_field'],
#       dtype='object', length=170)

# %%
df.shape
# Out:
# (260920, 170)

# %%
print(df.duplicated().sum())
# Out:
# 259825

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1095, 170)

# %%
df.columns
# Out:
# Index(['match_id', 'winner', 'year', 'month', 'day', 'season_2008',
#        'season_2009', 'season_2010', 'season_2011', 'season_2012',
#        ...
#        'toss_winner_Lucknow Super Giants', 'toss_winner_Mumbai Indians',
#        'toss_winner_Pune Warriors', 'toss_winner_Punjab Kings',
#        'toss_winner_Rajasthan Royals', 'toss_winner_Rising Pune Supergiant',
#        'toss_winner_Royal Challengers Bengaluru',
#        'toss_winner_Sunrisers Hyderabad', 'toss_decision_bat',
#        'toss_decision_field'],
#       dtype='object', length=170)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

x = df.drop('winner',axis=1)
y = df['winner']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model = RandomForestClassifier(n_estimators=500)
model.fit(x_train,y_train)
y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)

accuracy_test = accuracy_score(y_test,y_pred_test)
accuracy_train = accuracy_score(y_train,y_pred_train)
print('training accuracy:-',accuracy_train)
print('testing accuarcy:-',accuracy_test)
# Out:
# training accuracy:- 1.0
# testing accuarcy:- 0.5205479452054794

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

x = df.drop('winner',axis=1)
y = df['winner']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model = XGBClassifier(n_estimators=1000)
model.fit(x_train,y_train)
y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)

accuracy_test = accuracy_score(y_test,y_pred_test)
accuracy_train = accuracy_score(y_train,y_pred_train)
print('training accuracy:-',accuracy_train)
print('testing accuarcy:-',accuracy_test)
# Out:
# training accuracy:- 1.0
# testing accuarcy:- 0.5296803652968036

# %%
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score

x = df.drop('winner',axis=1)
y = df['winner']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model = CatBoostClassifier(n_estimators=500)
model.fit(x_train,y_train)
y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)

accuracy_test = accuracy_score(y_test,y_pred_test)
accuracy_train = accuracy_score(y_train,y_pred_train)
print('training accuracy:-',accuracy_train)
print('testing accuarcy:-',accuracy_test)
# Out:
# Learning rate set to 0.141176
# 0:	learn: 2.6004085	total: 162ms	remaining: 1m 20s
# 1:	learn: 2.4961185	total: 179ms	remaining: 44.6s
# 2:	learn: 2.4039796	total: 196ms	remaining: 32.5s
# 3:	learn: 2.2856463	total: 211ms	remaining: 26.2s
# 4:	learn: 2.1608988	total: 228ms	remaining: 22.5s
# 5:	learn: 2.1022356	total: 244ms	remaining: 20.1s
# 6:	learn: 2.0226673	total: 261ms	remaining: 18.4s
# 7:	learn: 1.9787985	total: 277ms	remaining: 17s
# 8:	learn: 1.9371365	total: 293ms	remaining: 16s
# 9:	learn: 1.9055175	total: 309ms	remaining: 15.1s
# 10:	learn: 1.8676528	total: 324ms	remaining: 14.4s
# 11:	learn: 1.7990975	total: 340ms	remaining: 13.8s
# 12:	learn: 1.7632870	total: 357ms	remaining: 13.4s
# 13:	learn: 1.7239674	total: 373ms	remaining: 13s
# 14:	learn: 1.6947792	total: 390ms	remaining: 12.6s
# 15:	learn: 1.6632384	total: 406ms	remaining: 12.3s
# 16:	learn: 1.6379143	total: 423ms	remaining: 12s
# 17:	learn: 1.6100408	total: 439ms	remaining: 11.8s
# ...
